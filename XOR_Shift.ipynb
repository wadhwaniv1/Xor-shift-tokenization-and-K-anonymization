# %% [markdown]
# <a href="https://colab.research.google.com/github/wadhwaniv1/Xor-shift-tokenization-and-K-anonymization/blob/master/XOR_Shift.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import random

# %%
df = pd.read_csv('/content/HRDataset_v14.csv')
df.head()
# Out:
#               Employee_Name  EmpID  ...  DaysLateLast30  Absences
# 0       Adinolfi, Wilson  K  10026  ...               0         1
# 1  Ait Sidi, Karthikeyan     10084  ...               0        17
# 2         Akinkuolie, Sarah  10196  ...               0         3
# 3              Alagbe,Trina  10088  ...               0        15
# 4          Anderson, Carol   10069  ...               0         2
#
# [5 rows x 36 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 311 entries, 0 to 310
# Data columns (total 36 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Employee_Name               311 non-null    object
#  1   EmpID                       311 non-null    int64
#  2   MarriedID                   311 non-null    int64
#  3   MaritalStatusID             311 non-null    int64
#  4   GenderID                    311 non-null    int64
#  5   EmpStatusID                 311 non-null    int64
#  6   DeptID                      311 non-null    int64
#  7   PerfScoreID                 311 non-null    int64
#  8   FromDiversityJobFairID      311 non-null    int64
#  9   Salary                      311 non-null    int64
#  10  Termd                       311 non-null    int64
#  11  PositionID                  311 non-null    int64
#  12  Position                    311 non-null    object
# ...

# %%
df.describe()
# Out:
#               EmpID   MarriedID  ...  DaysLateLast30    Absences
# count    311.000000  311.000000  ...      311.000000  311.000000
# mean   10156.000000    0.398714  ...        0.414791   10.237942
# std       89.922189    0.490423  ...        1.294519    5.852596
# min    10001.000000    0.000000  ...        0.000000    1.000000
# 25%    10078.500000    0.000000  ...        0.000000    5.000000
# 50%    10156.000000    0.000000  ...        0.000000   10.000000
# 75%    10233.500000    1.000000  ...        0.000000   15.000000
# max    10311.000000    1.000000  ...        6.000000   20.000000
#
# [8 rows x 18 columns]

# %%
df.shape
# Out:
# (311, 36)

# %%
x = list(df.Employee_Name[1])
x
# Out:
# ['A',
#  'i',
#  't',
#  ' ',
#  'S',
#  'i',
#  'd',
#  'i',
#  ',',
#  ' ',
#  'K',
#  'a',
#  'r',
#  't',
#  'h',
#  'i',
#  'k',
#  'e',
#  'y',
#  'a',
#  'n',
#  ' ',
#  ' ',
#  ' ']

# %%
for i in range(len(x)):
    x[i] = str(ord(x[i]))
x
# Out:
# ['65',
#  '105',
#  '116',
#  '32',
#  '83',
#  '105',
#  '100',
#  '105',
#  '44',
#  '32',
#  '75',
#  '97',
#  '114',
#  '116',
#  '104',
#  '105',
#  '107',
#  '101',
#  '121',
#  '97',
#  '110',
#  '32',
#  '32',
#  '32']

# %%
in_token = ''.join(x)
x = int(''.join(x))
x
# Out:
# 6510511632831051001054432759711411610410510710112197110323232

# %%
n = random.randint(1,9)
print("Random number",n)
y = x << n
print("Shifted x ",y)
z = str(x^y)
print("Xored x^y ",z)
z = list(z)
print(z)
# Out:
# Random number 1
# Shifted x  13021023265662102002108865519422823220821021420224394220646464
# Xored x^y  19430408582181278030189479498240976280215372523029042299627616
# ['1', '9', '4', '3', '0', '4', '0', '8', '5', '8', '2', '1', '8', '1', '2', '7', '8', '0', '3', '0', '1', '8', '9', '4', '7', '9', '4', '9', '8', '2', '4', '0', '9', '7', '6', '2', '8', '0', '2', '1', '5', '3', '7', '2', '5', '2', '3', '0', '2', '9', '0', '4', '2', '2', '9', '9', '6', '2', '7', '6', '1', '6']

# %%
for i in range(len(z)):
    z[i] = int(z[i])%26+65
print(z)

for i in range(len(z)):
    z[i] = chr(z[i])
print(z)
# Out:
# [66, 74, 69, 68, 65, 69, 65, 73, 70, 73, 67, 66, 73, 66, 67, 72, 73, 65, 68, 65, 66, 73, 74, 69, 72, 74, 69, 74, 73, 67, 69, 65, 74, 72, 71, 67, 73, 65, 67, 66, 70, 68, 72, 67, 70, 67, 68, 65, 67, 74, 65, 69, 67, 67, 74, 74, 71, 67, 72, 71, 66, 71]
# ['B', 'J', 'E', 'D', 'A', 'E', 'A', 'I', 'F', 'I', 'C', 'B', 'I', 'B', 'C', 'H', 'I', 'A', 'D', 'A', 'B', 'I', 'J', 'E', 'H', 'J', 'E', 'J', 'I', 'C', 'E', 'A', 'J', 'H', 'G', 'C', 'I', 'A', 'C', 'B', 'F', 'D', 'H', 'C', 'F', 'C', 'D', 'A', 'C', 'J', 'A', 'E', 'C', 'C', 'J', 'J', 'G', 'C', 'H', 'G', 'B', 'G']

# %%
f_token = ''.join(z)
print("Token" + '1' + ">>" + f_token)
df.at[1,'Employee_Name'] = f_token
df.head()
# Out:
# Token1>>BJEDAEAIFICBIBCHIADABIJEHJEJICEAJHGCIACBFDHCFCDACJAECCJJGCHGBG
#                                        Employee_Name  ...  Absences
# 0                                Adinolfi, Wilson  K  ...         1
# 1  BJEDAEAIFICBIBCHIADABIJEHJEJICEAJHGCIACBFDHCFC...  ...        17
# 2                                  Akinkuolie, Sarah  ...         3
# 3                                       Alagbe,Trina  ...        15
# 4                                   Anderson, Carol   ...         2
#
# [5 rows x 36 columns]

# %%
print('Initial token length',len(in_token))
print('Final token length',len(f_token))
# Out:
# Initial token length 61
# Final token length 62

# %%
for j in range(0,310):
  x = list(df.Employee_Name[j])
  for i in range(len(x)):
    x[i] = str(ord(x[i]))
  x = int(''.join(x))
  n = random.randint(1,9)
  y = x << n
  z = str(x^y)
  z = list(z)
  for i in range(len(z)):
    z[i] = int(z[i])%26+65
  for i in range(len(z)):
    z[i] = chr(z[i])
  print("Token" + str(j) + ">>" + ''.join(z))
  df.at[j,'Employee_Name'] = ''.join(z)

df.to_csv("HRDataset_v13.csv", index=False)
# Out:
# Token0>>IDIEGEEJHBBCGFFBBDBDJBDECEEDHIADDGBDIFJCGHFCBFDHIIJB
# Token1>>BBAGHGJHICJCBEEHAEHBCDJHJBEEIECECAEIGHCCJIACEEDBFGDEHGBDCGEJFAE
# Token2>>EBHHFHJEIDIGIJAGHADJHGJIAEFHICCAJJDCACJBICJDDJC
# Token3>>DDCHDAFDIHHDGEBGGHEJDIECDCHGFCAIJ
# Token4>>BGHAIHABEDCBGEHJFDJDEAHFAIFHDIIGDHGJDBHJEGCII
# Token5>>EIDGEJGBHHGBAIGEHJFDEEEIGECBJDBHJBIDJBIHBJHJC
# Token6>>ECAGCIAHECDIGDICEDCAJJGECBHHBDCBBHAAGABGJ
# Token7>>BJBEHJGBFABBFAGBAFCHDFFHGJCH
# Token8>>IFAHGHBFCFAJEGBJBFGEIBJJEAHHGFAIJBAHHFBDEF
# Token9>>DCAFBFCIJAGDHCAAEGBAJCFJCGJHDGJDCDBAFJIDIDBIGGI
# Token10>>EHBBFFGBACDCACGIJGDCGGJHBIGACIHFAJEFAJGJGAIAAJADDG
# Token11>>BBDHHJBCJHECAIGECEHAHGCJBIFDBDJJDBACID
# Token12>>BHBJHHFDJDECHEICIIACBBFDBICFFGCEAJGBGJFFBEG
# Token13>>BHAJCDHCBBHJJCEJACGIJHEFDJFJAHHDBDADGAHDBFIHBBCDADDH
# Token14>>DDEIEDICAAAJBACFHJGBHHBCBIEGHGIBEG
# Token15>>CAIABHCFDCEAHJIBCCCBCIFDJDHEAHJABJI
# Token16>>JJJCADBAIDAIHHCJCAFADAECFCJIGBGADDDGABDCI
# Token17>>DDIABHIIJHBAICBCJDACFFBAGIEIEHEHJBBGHFFFDIIFICHHDCBAA
# ...

# %%
#Anonymization
df1 = df[['ManagerName','Salary','Sex']]
df1.head()
# Out:
#       ManagerName  Salary Sex
# 0  Michael Albert   62506  M
# 1      Simon Roup  104437  M
# 2  Kissy Sullivan   64955   F
# 3    Elijiah Gray   64991   F
# 4  Webster Butler   50825   F

# %%
sum_sal = sum(df['Salary'])
sum_sal
# Out:
# 21465433

# %%
df1['Salary'].describe()
# Out:
# count       311.000000
# mean      69020.684887
# std       25156.636930
# min       45046.000000
# 25%       55501.500000
# 50%       62810.000000
# 75%       72036.000000
# max      250000.000000
# Name: Salary, dtype: float64

# %%
df1[df1['Salary']<60000].count()
# Out:
# ManagerName    121
# Salary         121
# Sex            121
# dtype: int64

# %%
df1[(df1['Salary']>=60000) & (df1['Salary']<70000)].count()
# Out:
# ManagerName    101
# Salary         101
# Sex            101
# dtype: int64

# %%
df1[df1['Salary']>=70000].count()
# Out:
# ManagerName    89
# Salary         89
# Sex            89
# dtype: int64

# %%
new_mean = (121*60000 + 101*(65000) + 89*(70000)) / 311
new_mean
# Out:
# 64485.53054662379

# %%
def anonymize(dataset, columns):
    """
    Anonymize certain columns of the database
    using suppression and generalization 
    """

    anon_dataset = dataset.copy()
    
    # Target all sensitive columns
    for column in columns:
        column_label = column['label']
        if column['type'] == 'suppressed':
            # Replace all characters with asterix
            anon_dataset[column_label] = ['*' for x in anon_dataset[column_label]]
        
        if column['type'] == 'semi-suppressed':
            # Replace 70% of the characters with asterix
            anon_dataset[column_label] = [('*'*(round(len(x)*.7)) + x[(round(len(x)*.7)):]) for x in anon_dataset[column_label]]
        
        if column['type'] == 'generalized':
            # Summarize the data using ranges
            for i in range(len(anon_dataset[column_label])):
                # convert column type from int to string
                anon_dataset[column_label] = anon_dataset[column_label].astype(str)
                x = int(anon_dataset[column_label][i])
                if x < 60000: anon_dataset[column_label][i] =  "< 60000"
                if x >= 60000 and x < 70000: anon_dataset[column_label][i] =  "60000-70000"
                if x >= 70000: anon_dataset[column_label][i] =  "> 70000"

    return anon_dataset


columns = [
    {"label": "ManagerName", "type": "semi-suppressed"},
    {"label": "Sex", "type": "suppressed"},
    {"label": "Salary", "type": "generalized"}
]

dataset = df1
anonymized_dataset = anonymize(dataset, columns)

# %%
anonymized_dataset
# Out:
#         ManagerName       Salary Sex
# 0    **********bert  60000-70000   *
# 1        *******oup      > 70000   *
# 2    **********ivan  60000-70000   *
# 3      ********Gray  60000-70000   *
# 4    **********tler      < 60000   *
# ..              ...          ...  ..
# 306  **********ivan  60000-70000   *
# 307  **********ller      < 60000   *
# 308      *******ing      > 70000   *
# 309      *******oup      > 70000   *
# 310   *********nley      < 60000   *
#
# [311 rows x 3 columns]
